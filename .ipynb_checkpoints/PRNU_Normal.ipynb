# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\inamy\anaconda3\lib\site-packages (4.12.0.88)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-1.23.5
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.2.6 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.2.6 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.2.6 which is incompatible.
# scipy 1.11.4 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.2.6 which is incompatible.
# streamlit 1.30.0 requires numpy<2,>=1.19.3, but you have numpy 2.2.6 which is incompatible.

# %%
pip install -r ../prnu-python/requirements.txt
# Out:
# Requirement already satisfied: numpy==1.23.5 in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 1)) (1.23.5)
# Requirement already satisfied: pillow in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 2)) (10.2.0)
# Requirement already satisfied: pywavelets in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 3)) (1.5.0)
# Requirement already satisfied: scipy in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 4)) (1.11.4)
# Requirement already satisfied: scikit-learn in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: tqdm in c:\users\inamy\anaconda3\lib\site-packages (from -r ../prnu-python/requirements.txt (line 6)) (4.65.0)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\inamy\anaconda3\lib\site-packages (from scikit-learn->-r ../prnu-python/requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\inamy\anaconda3\lib\site-packages (from scikit-learn->-r ../prnu-python/requirements.txt (line 5)) (2.2.0)
# Requirement already satisfied: colorama in c:\users\inamy\anaconda3\lib\site-packages (from tqdm->-r ../prnu-python/requirements.txt (line 6)) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append(r'C:\Users\inamy\Desktop\prnu-camera-source-detection\prnu-python')

# %%
pip install --user numpy
# Out:
# Requirement already satisfied: numpy in c:\users\inamy\anaconda3\lib\site-packages (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\inamy\anaconda3\lib\site-packages (4.12.0.88)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Installing collected packages: numpy
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts f2py.exe and numpy-config.exe are installed in 'C:\Users\inamy\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# astropy 5.3.4 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# matplotlib 3.8.0 requires numpy<2,>=1.21, but you have numpy 2.2.6 which is incompatible.
# numba 0.59.0 requires numpy<1.27,>=1.22, but you have numpy 2.2.6 which is incompatible.
# pandas 2.1.4 requires numpy<2,>=1.23.2; python_version == "3.11", but you have numpy 2.2.6 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.2.6 which is incompatible.
# scipy 1.11.4 requires numpy<1.28.0,>=1.21.6, but you have numpy 2.2.6 which is incompatible.
# streamlit 1.30.0 requires numpy<2,>=1.19.3, but you have numpy 2.2.6 which is incompatible.

# %%
pip install --user PyWavelets
# Out:
# Requirement already satisfied: PyWavelets in c:\users\inamy\anaconda3\lib\site-packages (1.5.0)
# Collecting numpy<2.0,>=1.22.4 (from PyWavelets)
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.6
#     Uninstalling numpy-2.2.6:
#       Successfully uninstalled numpy-2.2.6
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'C:\Users\inamy\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.

# %%
pip install --user scipy
# Out:
# Requirement already satisfied: scipy in c:\users\inamy\anaconda3\lib\site-packages (1.11.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\inamy\appdata\roaming\python\python311\site-packages (from scipy) (1.26.4)

# %%
pip install --user matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\inamy\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\inamy\appdata\roaming\python\python311\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\inamy\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\inamy\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user glob2
# Out:
# Requirement already satisfied: glob2 in c:\users\inamy\appdata\roaming\python\python311\site-packages (0.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\inamy\anaconda3\lib\site-packages (1.2.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\inamy\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\inamy\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\inamy\anaconda3\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\inamy\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
from glob import glob

# Add prnu-python folder to path
sys.path.append('../prnu-python')

from prnu import *

print("✅ Setup complete. All libraries and PRNU functions are ready to use.")
# Out:
# ✅ Setup complete. All libraries and PRNU functions are ready to use.

# %%
import os
import glob
import numpy as np
from PIL import Image
from prnu import extract_multiple_aligned, crosscorr_2d

print("✅ Successfully imported PRNU functions.")

## ---------------------------------------------------------------------------
## PART 1: CREATE AND SAVE FINGERPRINTS FOR EACH CAMERA
## ---------------------------------------------------------------------------

data_directory = r"C:\Users\inamy\Desktop\prnu-camera-source-detection\data"
fingerprint_directory = os.path.join(os.path.dirname(data_directory), 'fingerprints')
os.makedirs(fingerprint_directory, exist_ok=True)

device_folders = [f for f in os.listdir(data_directory) if os.path.isdir(os.path.join(data_directory, f))]
print(f"Found device folders: {device_folders}")

for device in device_folders:
    print(f"\nProcessing fingerprint images for: {device}...")

    # Get all JPG/JPEG images regardless of case
    image_paths = glob.glob(os.path.join(data_directory, device, 'images', 'fingerprint_set', '*.[jJ][pP][gG]')) + \
                  glob.glob(os.path.join(data_directory, device, 'images', 'fingerprint_set', '*.[jJ][pP][eE][gG]'))

    if not image_paths:
        print(f"⚠️  No images found for {device} fingerprint_set. Skipping.")
        continue

    TARGET_WIDTH = 1024
    TARGET_HEIGHT = 768

    # Read images using PIL
    images = []
    for path in image_paths:
        try:
            img = Image.open(path).convert('RGB')  # Ensure 3 channels
            img = img.resize((TARGET_WIDTH, TARGET_HEIGHT), Image.LANCZOS)
            img_np = np.array(img, dtype=np.uint8)
            images.append(img_np)
        except Exception as e:
            print(f"⚠️ Could not read image: {path} ({e})")

    if not images:
        print(f"⚠️ No valid images for {device}. Skipping.")
        continue

    shapes = set([img.shape for img in images])
    if len(shapes) != 1:
        print(f"❌ Mismatched shapes in {device}: {shapes}")
        continue

    print(f"Number of images for {device}: {len(images)}")
    for idx, im in enumerate(images):
        print(f"  Image {idx} shape: {im.shape}, dtype: {im.dtype}")
    
    # Extract the camera fingerprint
    fingerprint = extract_multiple_aligned(images, processes=0)

    # Save the fingerprint
    save_path = os.path.join(fingerprint_directory, f"{device}_fingerprint.npy")
    np.save(save_path, fingerprint)
    print(f"✅ Fingerprint for {device} saved to: {save_path}")
# Out:
# ✅ Successfully imported PRNU functions.
# Found device folders: ['iphone15', 'OnePlus Nord CE4', 'Samsung S21 FE', 'Samsung S23 5g']
#
# Processing fingerprint images for: iphone15...
# Number of images for iphone15: 70
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 70/70 [00:38<00:00,  1.83it/s]
# ✅ Fingerprint for iphone15 saved to: C:\Users\inamy\Desktop\prnu-camera-source-detection\fingerprints\iphone15_fingerprint.npy
#
# Processing fingerprint images for: OnePlus Nord CE4...
# Number of images for OnePlus Nord CE4: 74
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 74/74 [00:46<00:00,  1.59it/s]
# ✅ Fingerprint for OnePlus Nord CE4 saved to: C:\Users\inamy\Desktop\prnu-camera-source-detection\fingerprints\OnePlus Nord CE4_fingerprint.npy
#
# Processing fingerprint images for: Samsung S21 FE...
# Number of images for Samsung S21 FE: 75
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
#   Image 74 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 75/75 [00:46<00:00,  1.62it/s]
# ✅ Fingerprint for Samsung S21 FE saved to: C:\Users\inamy\Desktop\prnu-camera-source-detection\fingerprints\Samsung S21 FE_fingerprint.npy
#
# Processing fingerprint images for: Samsung S23 5g...
# Number of images for Samsung S23 5g: 74
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 74/74 [00:45<00:00,  1.63it/s]
# ✅ Fingerprint for Samsung S23 5g saved to: C:\Users\inamy\Desktop\prnu-camera-source-detection\fingerprints\Samsung S23 5g_fingerprint.npy

# %%
## ---------------------------------------------------------------------------
## PART 2: MATCH AN UNKNOWN IMAGE
## ---------------------------------------------------------------------------
print("\n--- Starting Image Matching Test ---")

unknown_image_path = r"C:\Users\inamy\Desktop\prnu-camera-source-detection\data\iphone15\images\query_set\6A38C3E6-08D8-419C-A3EE-2E09D8CDCF14.jpeg"
print(f"Testing image: {unknown_image_path}")

# Read query image with PIL and resize to match fingerprint size
TARGET_WIDTH = 1024
TARGET_HEIGHT = 768

try:
    unknown_img = Image.open(unknown_image_path).convert('RGB')
    unknown_img = unknown_img.resize((TARGET_WIDTH, TARGET_HEIGHT), Image.LANCZOS)
    unknown_np = np.array(unknown_img, dtype=np.uint8)
except Exception as e:
    raise ValueError(f"Could not read query image: {unknown_image_path} ({e})")

# ✅ Extract noise residual from the unknown image
from prnu.functions import noise_extract_compact, rgb2gray

query_noise = noise_extract_compact((unknown_np, 4, 2))  # levels=4, sigma=2 is standard
query_noise_gray = rgb2gray(query_noise)

# Load all fingerprints
fingerprints = {}
for fp_file in os.listdir(fingerprint_directory):
    if fp_file.endswith('.npy'):
        device_name = fp_file.replace('_fingerprint.npy', '')
        fingerprints[device_name] = np.load(os.path.join(fingerprint_directory, fp_file))

print(f"Loaded {len(fingerprints)} fingerprints for matching.")

# Compare unknown image against each fingerprint
best_match_device = None
highest_correlation = -1

for device, fingerprint in fingerprints.items():
    # Convert fingerprint to grayscale if not already
    if fingerprint.ndim == 3:
        fp_gray = rgb2gray(fingerprint)
    else:
        fp_gray = fingerprint

    # crosscorr_2d returns a map; take max correlation as score
    correlation_map = crosscorr_2d(query_noise_gray, fp_gray)
    correlation_score = float(np.max(correlation_map))

    print(f"  - Correlation with {device}: {correlation_score:.4f}")

    if correlation_score > highest_correlation:
        highest_correlation = correlation_score
        best_match_device = device

print("\n--- Results ---")
if best_match_device is not None:
    print(f"🚀 The best match for the image is: **{best_match_device}** with a score of {highest_correlation:.4f}")
else:
    print("⚠️ No match found.")
# Out:
# --- Starting Image Matching Test ---
# Testing image: C:\Users\inamy\Desktop\prnu-camera-source-detection\data\iphone15\images\query_set\6A38C3E6-08D8-419C-A3EE-2E09D8CDCF14.jpeg
# Loaded 4 fingerprints for matching.
#   - Correlation with iphone15: 20943.0117
#   - Correlation with OnePlus Nord CE4: 1159.3610
#   - Correlation with Samsung S21 FE: 1159.8114
#   - Correlation with Samsung S23 5g: 1205.3734
#
# --- Results ---
# 🚀 The best match for the image is: **iphone15** with a score of 20943.0117

# %%
import os
import glob
from PIL import Image
import numpy as np
import sys

# >>>>>> CRITICAL: Import all necessary functions from the PRNU library <<<<<<
# You must ensure the 'prnu' library folder is correctly linked in your environment's path
try:
    from prnu import crosscorr_2d
    from prnu.functions import noise_extract_compact, rgb2gray 
except ImportError as e:
    sys.exit(f"❌ FATAL ERROR: Cannot import PRNU functions. Please check your setup. Error: {e}")
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# --- CONFIGURATION ---
data_directory = r"C:\Users\inamy\Desktop\prnu-camera-source-detection\data"
fingerprint_directory = os.path.join(os.path.dirname(data_directory), 'fingerprints')

# Define the folder to test and its known source
QUERY_FOLDER_PATH = r"C:\Users\inamy\Desktop\prnu-camera-source-detection\data\OnePlus Nord CE4\images\query_set"
CORRECT_SOURCE = 'OnePlus Nord CE4' 

# Standard resizing parameters
TARGET_WIDTH = 1024
TARGET_HEIGHT = 768

## ---------------------------------------------------------------------------
## PART 1: LOAD FINGERPRINTS
## ---------------------------------------------------------------------------

fingerprints = {}
for fp_file in os.listdir(fingerprint_directory):
    if fp_file.endswith('.npy'):
        device_name = fp_file.replace('_fingerprint.npy', '')
        fingerprints[device_name] = np.load(os.path.join(fingerprint_directory, fp_file))

if not fingerprints:
    sys.exit("❌ ERROR: No fingerprints loaded. Check the 'fingerprint_directory' path.")

print(f"Loaded {len(fingerprints)} fingerprints for matching: {list(fingerprints.keys())}")


## ---------------------------------------------------------------------------
## PART 2: BATCH MATCHING (CROSS-CORRELATION) AND ACCURACY
## ---------------------------------------------------------------------------
print("\n--- Starting Batch Traditional Correlation (PCE) Test ---")
print(f"Known correct source: {CORRECT_SOURCE}")

query_image_paths = glob.glob(os.path.join(QUERY_FOLDER_PATH, '*.[jJ][pP][gG]')) + \
                    glob.glob(os.path.join(QUERY_FOLDER_PATH, '*.[jJ][pP][eE][gG]'))

total_images = 0
correct_identifications = 0

if not query_image_paths:
    print("⚠️ No query images found in the specified folder.")
else:
    for image_path in query_image_paths:
        total_images += 1
        
        # 1. Image and Noise Residual Extraction 
        try:
            unknown_img = Image.open(image_path).convert('RGB')
            unknown_img = unknown_img.resize((TARGET_WIDTH, TARGET_HEIGHT), Image.LANCZOS)
            unknown_np = np.array(unknown_img, dtype=np.uint8)
        except:
            continue
        
        # Extract noise residual and convert to grayscale (Uses the actual PRNU functions)
        query_noise = noise_extract_compact((unknown_np, 4, 2))
        query_noise_gray = rgb2gray(query_noise)

        # 2. Compare against all fingerprints
        best_match_device = None
        highest_correlation = -1.0
        
        for device, fingerprint in fingerprints.items():
            
            # Convert fingerprint to grayscale
            fp_gray = rgb2gray(fingerprint) if fingerprint.ndim == 3 else fingerprint

            # Calculate Cross-Correlation Score (PCE)
            correlation_map = crosscorr_2d(query_noise_gray, fp_gray)
            correlation_score = float(np.max(correlation_map))

            if correlation_score > highest_correlation:
                highest_correlation = correlation_score
                best_match_device = device
        
        # 3. Tally Accuracy
        is_correct = (best_match_device == CORRECT_SOURCE)
        
        if is_correct:
            correct_identifications += 1
            
        print(f"  Processed {os.path.basename(image_path):<30}: Identified as {best_match_device} ({'Correct' if is_correct else 'Incorrect'}). Score: {highest_correlation:.4f}")

## ---------------------------------------------------------------------------
## FINAL ACCURACY REPORT
## ---------------------------------------------------------------------------

print("\n" + "="*80)
print("           FINAL ACCURACY REPORT - TRADITIONAL CORRELATION")
print("="*80)

if total_images > 0:
    accuracy = (correct_identifications / total_images) * 100
    print(f"Total Images Processed: {total_images}")
    print(f"Correct Identifications: {correct_identifications}")
    print(f"Accuracy for {CORRECT_SOURCE} folder: **{accuracy:.2f}%** 🎯")
else:
    print("Could not calculate accuracy as zero valid images were processed.")
# Out:
# Loaded 4 fingerprints for matching: ['iphone15', 'OnePlus Nord CE4', 'Samsung S21 FE', 'Samsung S23 5g']
#
# --- Starting Batch Traditional Correlation (PCE) Test ---
# Known correct source: OnePlus Nord CE4
#   Processed IMG20251004162429.jpg         : Identified as OnePlus Nord CE4 (Correct). Score: 1156.1511
#   Processed IMG20251004162534.jpg         : Identified as iphone15 (Incorrect). Score: 831.6960
#   Processed IMG20251004162710.jpg         : Identified as OnePlus Nord CE4 (Correct). Score: 1615.8977
#   Processed IMG20251004162719.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 318.1390
#   Processed IMG20251004162731.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 1195.1433
#   Processed IMG20251004162928.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 1632.7958
#   Processed IMG20251004163054_01.jpg      : Identified as Samsung S23 5g (Incorrect). Score: 828.8396
#   Processed IMG20251004163055.jpg         : Identified as OnePlus Nord CE4 (Correct). Score: 829.8776
#   Processed IMG20251004163258.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 829.2788
#   Processed IMG20251004163416.jpg         : Identified as iphone15 (Incorrect). Score: 1779.2296
#   Processed IMG20251004163448.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 455.7901
#   Processed IMG20251004163901.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 1603.1125
#   Processed IMG20251004204647.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 1903.3999
#   Processed IMG20251004204706.jpg         : Identified as OnePlus Nord CE4 (Correct). Score: 983.7483
#   Processed IMG20251004204758.jpg         : Identified as Samsung S21 FE (Incorrect). Score: 655.7941
#   Processed IMG20251004204838.jpg         : Identified as iphone15 (Incorrect). Score: 1035.5599
#   Processed IMG20251004205053.jpg         : Identified as OnePlus Nord CE4 (Correct). Score: 687.2647
#   Processed IMG20251004205134.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 808.6362
#   Processed IMG20251004205505.jpg         : Identified as Samsung S23 5g (Incorrect). Score: 1596.5085
#   Processed IMG20251004205526.jpg         : Identified as Samsung S21 FE (Incorrect). Score: 1812.1733
#
# ================================================================================
#            FINAL ACCURACY REPORT - TRADITIONAL CORRELATION
# ================================================================================
# Total Images Processed: 20
# Correct Identifications: 5
# Accuracy for OnePlus Nord CE4 folder: **25.00%** 🎯
