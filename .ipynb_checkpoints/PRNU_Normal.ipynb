# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.12.0.88)
# Collecting numpy<2.3.0,>=2 (from opencv-python)
#   Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp312-cp312-macosx_14_0_arm64.whl (5.1 MB)
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.3 requires numpy<2.0,>=1.18.5, but you have numpy 2.2.6 which is incompatible.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.2.6 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.6 which is incompatible.
# Successfully installed numpy-2.2.6
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r ../prnu-python/requirements.txt
# Out:
# python(28692) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Collecting numpy==1.23.5 (from -r ../prnu-python/requirements.txt (line 1))
#   Using cached numpy-1.23.5.tar.gz (10.7 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [33 lines of output]
#       Traceback (most recent call last):
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 112, in get_requires_for_build_wheel
#           backend = _build_backend()
#                     ^^^^^^^^^^^^^^^^
#         File "/opt/anaconda3/lib/python3.12/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 77, in _build_backend
#           obj = import_module(mod_path)
#                 ^^^^^^^^^^^^^^^^^^^^^^^
#         File "/opt/anaconda3/lib/python3.12/importlib/__init__.py", line 90, in import_module
#           return _bootstrap._gcd_import(name[level:], package, level)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#         File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#         File "<frozen importlib._bootstrap>", line 1331, in _find_and_load_unlocked
#         File "<frozen importlib._bootstrap>", line 935, in _load_unlocked
#         File "<frozen importlib._bootstrap_external>", line 995, in exec_module
#         File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#         File "/private/var/folders/m2/h5vdkxbd07x_1vpjxprssq740000gn/T/pip-build-env-7be3dy14/overlay/lib/python3.12/site-packages/setuptools/__init__.py", line 16, in <module>
#           import setuptools.version
#         File "/private/var/folders/m2/h5vdkxbd07x_1vpjxprssq740000gn/T/pip-build-env-7be3dy14/overlay/lib/python3.12/site-packages/setuptools/version.py", line 1, in <module>
#           import pkg_resources
#         File "/private/var/folders/m2/h5vdkxbd07x_1vpjxprssq740000gn/T/pip-build-env-7be3dy14/overlay/lib/python3.12/site-packages/pkg_resources/__init__.py", line 2172, in <module>
#           register_finder(pkgutil.ImpImporter, find_on_path)
#                           ^^^^^^^^^^^^^^^^^^^
#       AttributeError: module 'pkgutil' has no attribute 'ImpImporter'. Did you mean: 'zipimporter'?
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
sys.path.append(r'/Users/shreetsu/prnu-camera-source-detection/prnu-python')

# %%
pip install --user numpy
# Out:
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.12/site-packages (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user opencv-python
# Out:
# Requirement already satisfied: opencv-python in /opt/anaconda3/lib/python3.12/site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from opencv-python) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user PyWavelets
# Out:
# Requirement already satisfied: PyWavelets in /opt/anaconda3/lib/python3.12/site-packages (1.7.0)
# Requirement already satisfied: numpy<3,>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from PyWavelets) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user scipy
# Out:
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /opt/anaconda3/lib/python3.12/site-packages (from scipy) (2.2.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/anaconda3/lib/python3.12/site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Collecting numpy>=1.23 (from matplotlib)
#   Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (61 kB)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Using cached numpy-1.26.4-cp312-cp312-macosx_11_0_arm64.whl (13.7 MB)
# Installing collected packages: numpy
#   WARNING: The script f2py is installed in '/Users/shreetsu/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed numpy-1.26.4
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --user glob2
# Out:
# Requirement already satisfied: glob2 in /Users/shreetsu/.local/lib/python3.12/site-packages (0.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in /Users/shreetsu/.local/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os
import numpy as np
import cv2
from matplotlib import pyplot as plt
from glob import glob

# Add prnu-python folder to path
sys.path.append('../prnu-python')

from prnu import *

print("✅ Setup complete. All libraries and PRNU functions are ready to use.")
# Out:
# ✅ Setup complete. All libraries and PRNU functions are ready to use.

# %%
import os
import glob
import numpy as np
from PIL import Image
from prnu import extract_multiple_aligned, crosscorr_2d

print("✅ Successfully imported PRNU functions.")

## ---------------------------------------------------------------------------
## PART 1: CREATE AND SAVE FINGERPRINTS FOR EACH CAMERA
## ---------------------------------------------------------------------------

data_directory = r"/Users/shreetsu/prnu-camera-source-detection/data"
fingerprint_directory = os.path.join(os.path.dirname(data_directory), 'fingerprints')
os.makedirs(fingerprint_directory, exist_ok=True)

device_folders = [f for f in os.listdir(data_directory) if os.path.isdir(os.path.join(data_directory, f))]
print(f"Found device folders: {device_folders}")

for device in device_folders:
    print(f"\nProcessing fingerprint images for: {device}...")

    # Get all JPG/JPEG images regardless of case
    image_paths = glob.glob(os.path.join(data_directory, device, 'images', 'fingerprint_set', '*.[jJ][pP][gG]')) + \
                  glob.glob(os.path.join(data_directory, device, 'images', 'fingerprint_set', '*.[jJ][pP][eE][gG]'))

    if not image_paths:
        print(f"⚠️  No images found for {device} fingerprint_set. Skipping.")
        continue

    TARGET_WIDTH = 1024
    TARGET_HEIGHT = 768

    # Read images using PIL
    images = []
    for path in image_paths:
        try:
            img = Image.open(path).convert('RGB')  # Ensure 3 channels
            img = img.resize((TARGET_WIDTH, TARGET_HEIGHT), Image.LANCZOS)
            img_np = np.array(img, dtype=np.uint8)
            images.append(img_np)
        except Exception as e:
            print(f"⚠️ Could not read image: {path} ({e})")

    if not images:
        print(f"⚠️ No valid images for {device}. Skipping.")
        continue

    shapes = set([img.shape for img in images])
    if len(shapes) != 1:
        print(f"❌ Mismatched shapes in {device}: {shapes}")
        continue

    print(f"Number of images for {device}: {len(images)}")
    for idx, im in enumerate(images):
        print(f"  Image {idx} shape: {im.shape}, dtype: {im.dtype}")
    
    # Extract the camera fingerprint
    fingerprint = extract_multiple_aligned(images, processes=0)

    # Save the fingerprint
    save_path = os.path.join(fingerprint_directory, f"{device}_fingerprint.npy")
    np.save(save_path, fingerprint)
    print(f"✅ Fingerprint for {device} saved to: {save_path}")
# Out:
# ✅ Successfully imported PRNU functions.
# Found device folders: ['Samsung S23 5g', 'iphone15', 'OnePlus Nord CE4', 'Samsung S21 FE']
#
# Processing fingerprint images for: Samsung S23 5g...
# Number of images for Samsung S23 5g: 74
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 74/74 [00:12<00:00,  5.75it/s]
# ✅ Fingerprint for Samsung S23 5g saved to: /Users/shreetsu/prnu-camera-source-detection/fingerprints/Samsung S23 5g_fingerprint.npy
#
# Processing fingerprint images for: iphone15...
# Number of images for iphone15: 149
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
#   Image 74 shape: (768, 1024, 3), dtype: uint8
#   Image 75 shape: (768, 1024, 3), dtype: uint8
#   Image 76 shape: (768, 1024, 3), dtype: uint8
#   Image 77 shape: (768, 1024, 3), dtype: uint8
#   Image 78 shape: (768, 1024, 3), dtype: uint8
#   Image 79 shape: (768, 1024, 3), dtype: uint8
#   Image 80 shape: (768, 1024, 3), dtype: uint8
#   Image 81 shape: (768, 1024, 3), dtype: uint8
#   Image 82 shape: (768, 1024, 3), dtype: uint8
#   Image 83 shape: (768, 1024, 3), dtype: uint8
#   Image 84 shape: (768, 1024, 3), dtype: uint8
#   Image 85 shape: (768, 1024, 3), dtype: uint8
#   Image 86 shape: (768, 1024, 3), dtype: uint8
#   Image 87 shape: (768, 1024, 3), dtype: uint8
#   Image 88 shape: (768, 1024, 3), dtype: uint8
#   Image 89 shape: (768, 1024, 3), dtype: uint8
#   Image 90 shape: (768, 1024, 3), dtype: uint8
#   Image 91 shape: (768, 1024, 3), dtype: uint8
#   Image 92 shape: (768, 1024, 3), dtype: uint8
#   Image 93 shape: (768, 1024, 3), dtype: uint8
#   Image 94 shape: (768, 1024, 3), dtype: uint8
#   Image 95 shape: (768, 1024, 3), dtype: uint8
#   Image 96 shape: (768, 1024, 3), dtype: uint8
#   Image 97 shape: (768, 1024, 3), dtype: uint8
#   Image 98 shape: (768, 1024, 3), dtype: uint8
#   Image 99 shape: (768, 1024, 3), dtype: uint8
#   Image 100 shape: (768, 1024, 3), dtype: uint8
#   Image 101 shape: (768, 1024, 3), dtype: uint8
#   Image 102 shape: (768, 1024, 3), dtype: uint8
#   Image 103 shape: (768, 1024, 3), dtype: uint8
#   Image 104 shape: (768, 1024, 3), dtype: uint8
#   Image 105 shape: (768, 1024, 3), dtype: uint8
#   Image 106 shape: (768, 1024, 3), dtype: uint8
#   Image 107 shape: (768, 1024, 3), dtype: uint8
#   Image 108 shape: (768, 1024, 3), dtype: uint8
#   Image 109 shape: (768, 1024, 3), dtype: uint8
#   Image 110 shape: (768, 1024, 3), dtype: uint8
#   Image 111 shape: (768, 1024, 3), dtype: uint8
#   Image 112 shape: (768, 1024, 3), dtype: uint8
#   Image 113 shape: (768, 1024, 3), dtype: uint8
#   Image 114 shape: (768, 1024, 3), dtype: uint8
#   Image 115 shape: (768, 1024, 3), dtype: uint8
#   Image 116 shape: (768, 1024, 3), dtype: uint8
#   Image 117 shape: (768, 1024, 3), dtype: uint8
#   Image 118 shape: (768, 1024, 3), dtype: uint8
#   Image 119 shape: (768, 1024, 3), dtype: uint8
#   Image 120 shape: (768, 1024, 3), dtype: uint8
#   Image 121 shape: (768, 1024, 3), dtype: uint8
#   Image 122 shape: (768, 1024, 3), dtype: uint8
#   Image 123 shape: (768, 1024, 3), dtype: uint8
#   Image 124 shape: (768, 1024, 3), dtype: uint8
#   Image 125 shape: (768, 1024, 3), dtype: uint8
#   Image 126 shape: (768, 1024, 3), dtype: uint8
#   Image 127 shape: (768, 1024, 3), dtype: uint8
#   Image 128 shape: (768, 1024, 3), dtype: uint8
#   Image 129 shape: (768, 1024, 3), dtype: uint8
#   Image 130 shape: (768, 1024, 3), dtype: uint8
#   Image 131 shape: (768, 1024, 3), dtype: uint8
#   Image 132 shape: (768, 1024, 3), dtype: uint8
#   Image 133 shape: (768, 1024, 3), dtype: uint8
#   Image 134 shape: (768, 1024, 3), dtype: uint8
#   Image 135 shape: (768, 1024, 3), dtype: uint8
#   Image 136 shape: (768, 1024, 3), dtype: uint8
#   Image 137 shape: (768, 1024, 3), dtype: uint8
#   Image 138 shape: (768, 1024, 3), dtype: uint8
#   Image 139 shape: (768, 1024, 3), dtype: uint8
#   Image 140 shape: (768, 1024, 3), dtype: uint8
#   Image 141 shape: (768, 1024, 3), dtype: uint8
#   Image 142 shape: (768, 1024, 3), dtype: uint8
#   Image 143 shape: (768, 1024, 3), dtype: uint8
#   Image 144 shape: (768, 1024, 3), dtype: uint8
#   Image 145 shape: (768, 1024, 3), dtype: uint8
#   Image 146 shape: (768, 1024, 3), dtype: uint8
#   Image 147 shape: (768, 1024, 3), dtype: uint8
#   Image 148 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 149/149 [00:24<00:00,  6.13it/s]
# ✅ Fingerprint for iphone15 saved to: /Users/shreetsu/prnu-camera-source-detection/fingerprints/iphone15_fingerprint.npy
#
# Processing fingerprint images for: OnePlus Nord CE4...
# Number of images for OnePlus Nord CE4: 150
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
#   Image 74 shape: (768, 1024, 3), dtype: uint8
#   Image 75 shape: (768, 1024, 3), dtype: uint8
#   Image 76 shape: (768, 1024, 3), dtype: uint8
#   Image 77 shape: (768, 1024, 3), dtype: uint8
#   Image 78 shape: (768, 1024, 3), dtype: uint8
#   Image 79 shape: (768, 1024, 3), dtype: uint8
#   Image 80 shape: (768, 1024, 3), dtype: uint8
#   Image 81 shape: (768, 1024, 3), dtype: uint8
#   Image 82 shape: (768, 1024, 3), dtype: uint8
#   Image 83 shape: (768, 1024, 3), dtype: uint8
#   Image 84 shape: (768, 1024, 3), dtype: uint8
#   Image 85 shape: (768, 1024, 3), dtype: uint8
#   Image 86 shape: (768, 1024, 3), dtype: uint8
#   Image 87 shape: (768, 1024, 3), dtype: uint8
#   Image 88 shape: (768, 1024, 3), dtype: uint8
#   Image 89 shape: (768, 1024, 3), dtype: uint8
#   Image 90 shape: (768, 1024, 3), dtype: uint8
#   Image 91 shape: (768, 1024, 3), dtype: uint8
#   Image 92 shape: (768, 1024, 3), dtype: uint8
#   Image 93 shape: (768, 1024, 3), dtype: uint8
#   Image 94 shape: (768, 1024, 3), dtype: uint8
#   Image 95 shape: (768, 1024, 3), dtype: uint8
#   Image 96 shape: (768, 1024, 3), dtype: uint8
#   Image 97 shape: (768, 1024, 3), dtype: uint8
#   Image 98 shape: (768, 1024, 3), dtype: uint8
#   Image 99 shape: (768, 1024, 3), dtype: uint8
#   Image 100 shape: (768, 1024, 3), dtype: uint8
#   Image 101 shape: (768, 1024, 3), dtype: uint8
#   Image 102 shape: (768, 1024, 3), dtype: uint8
#   Image 103 shape: (768, 1024, 3), dtype: uint8
#   Image 104 shape: (768, 1024, 3), dtype: uint8
#   Image 105 shape: (768, 1024, 3), dtype: uint8
#   Image 106 shape: (768, 1024, 3), dtype: uint8
#   Image 107 shape: (768, 1024, 3), dtype: uint8
#   Image 108 shape: (768, 1024, 3), dtype: uint8
#   Image 109 shape: (768, 1024, 3), dtype: uint8
#   Image 110 shape: (768, 1024, 3), dtype: uint8
#   Image 111 shape: (768, 1024, 3), dtype: uint8
#   Image 112 shape: (768, 1024, 3), dtype: uint8
#   Image 113 shape: (768, 1024, 3), dtype: uint8
#   Image 114 shape: (768, 1024, 3), dtype: uint8
#   Image 115 shape: (768, 1024, 3), dtype: uint8
#   Image 116 shape: (768, 1024, 3), dtype: uint8
#   Image 117 shape: (768, 1024, 3), dtype: uint8
#   Image 118 shape: (768, 1024, 3), dtype: uint8
#   Image 119 shape: (768, 1024, 3), dtype: uint8
#   Image 120 shape: (768, 1024, 3), dtype: uint8
#   Image 121 shape: (768, 1024, 3), dtype: uint8
#   Image 122 shape: (768, 1024, 3), dtype: uint8
#   Image 123 shape: (768, 1024, 3), dtype: uint8
#   Image 124 shape: (768, 1024, 3), dtype: uint8
#   Image 125 shape: (768, 1024, 3), dtype: uint8
#   Image 126 shape: (768, 1024, 3), dtype: uint8
#   Image 127 shape: (768, 1024, 3), dtype: uint8
#   Image 128 shape: (768, 1024, 3), dtype: uint8
#   Image 129 shape: (768, 1024, 3), dtype: uint8
#   Image 130 shape: (768, 1024, 3), dtype: uint8
#   Image 131 shape: (768, 1024, 3), dtype: uint8
#   Image 132 shape: (768, 1024, 3), dtype: uint8
#   Image 133 shape: (768, 1024, 3), dtype: uint8
#   Image 134 shape: (768, 1024, 3), dtype: uint8
#   Image 135 shape: (768, 1024, 3), dtype: uint8
#   Image 136 shape: (768, 1024, 3), dtype: uint8
#   Image 137 shape: (768, 1024, 3), dtype: uint8
#   Image 138 shape: (768, 1024, 3), dtype: uint8
#   Image 139 shape: (768, 1024, 3), dtype: uint8
#   Image 140 shape: (768, 1024, 3), dtype: uint8
#   Image 141 shape: (768, 1024, 3), dtype: uint8
#   Image 142 shape: (768, 1024, 3), dtype: uint8
#   Image 143 shape: (768, 1024, 3), dtype: uint8
#   Image 144 shape: (768, 1024, 3), dtype: uint8
#   Image 145 shape: (768, 1024, 3), dtype: uint8
#   Image 146 shape: (768, 1024, 3), dtype: uint8
#   Image 147 shape: (768, 1024, 3), dtype: uint8
#   Image 148 shape: (768, 1024, 3), dtype: uint8
#   Image 149 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 150/150 [00:24<00:00,  6.15it/s]
# ✅ Fingerprint for OnePlus Nord CE4 saved to: /Users/shreetsu/prnu-camera-source-detection/fingerprints/OnePlus Nord CE4_fingerprint.npy
#
# Processing fingerprint images for: Samsung S21 FE...
# Number of images for Samsung S21 FE: 75
#   Image 0 shape: (768, 1024, 3), dtype: uint8
#   Image 1 shape: (768, 1024, 3), dtype: uint8
#   Image 2 shape: (768, 1024, 3), dtype: uint8
#   Image 3 shape: (768, 1024, 3), dtype: uint8
#   Image 4 shape: (768, 1024, 3), dtype: uint8
#   Image 5 shape: (768, 1024, 3), dtype: uint8
#   Image 6 shape: (768, 1024, 3), dtype: uint8
#   Image 7 shape: (768, 1024, 3), dtype: uint8
#   Image 8 shape: (768, 1024, 3), dtype: uint8
#   Image 9 shape: (768, 1024, 3), dtype: uint8
#   Image 10 shape: (768, 1024, 3), dtype: uint8
#   Image 11 shape: (768, 1024, 3), dtype: uint8
#   Image 12 shape: (768, 1024, 3), dtype: uint8
#   Image 13 shape: (768, 1024, 3), dtype: uint8
#   Image 14 shape: (768, 1024, 3), dtype: uint8
#   Image 15 shape: (768, 1024, 3), dtype: uint8
#   Image 16 shape: (768, 1024, 3), dtype: uint8
#   Image 17 shape: (768, 1024, 3), dtype: uint8
#   Image 18 shape: (768, 1024, 3), dtype: uint8
#   Image 19 shape: (768, 1024, 3), dtype: uint8
#   Image 20 shape: (768, 1024, 3), dtype: uint8
#   Image 21 shape: (768, 1024, 3), dtype: uint8
#   Image 22 shape: (768, 1024, 3), dtype: uint8
#   Image 23 shape: (768, 1024, 3), dtype: uint8
#   Image 24 shape: (768, 1024, 3), dtype: uint8
#   Image 25 shape: (768, 1024, 3), dtype: uint8
#   Image 26 shape: (768, 1024, 3), dtype: uint8
#   Image 27 shape: (768, 1024, 3), dtype: uint8
#   Image 28 shape: (768, 1024, 3), dtype: uint8
#   Image 29 shape: (768, 1024, 3), dtype: uint8
#   Image 30 shape: (768, 1024, 3), dtype: uint8
#   Image 31 shape: (768, 1024, 3), dtype: uint8
#   Image 32 shape: (768, 1024, 3), dtype: uint8
#   Image 33 shape: (768, 1024, 3), dtype: uint8
#   Image 34 shape: (768, 1024, 3), dtype: uint8
#   Image 35 shape: (768, 1024, 3), dtype: uint8
#   Image 36 shape: (768, 1024, 3), dtype: uint8
#   Image 37 shape: (768, 1024, 3), dtype: uint8
#   Image 38 shape: (768, 1024, 3), dtype: uint8
#   Image 39 shape: (768, 1024, 3), dtype: uint8
#   Image 40 shape: (768, 1024, 3), dtype: uint8
#   Image 41 shape: (768, 1024, 3), dtype: uint8
#   Image 42 shape: (768, 1024, 3), dtype: uint8
#   Image 43 shape: (768, 1024, 3), dtype: uint8
#   Image 44 shape: (768, 1024, 3), dtype: uint8
#   Image 45 shape: (768, 1024, 3), dtype: uint8
#   Image 46 shape: (768, 1024, 3), dtype: uint8
#   Image 47 shape: (768, 1024, 3), dtype: uint8
#   Image 48 shape: (768, 1024, 3), dtype: uint8
#   Image 49 shape: (768, 1024, 3), dtype: uint8
#   Image 50 shape: (768, 1024, 3), dtype: uint8
#   Image 51 shape: (768, 1024, 3), dtype: uint8
#   Image 52 shape: (768, 1024, 3), dtype: uint8
#   Image 53 shape: (768, 1024, 3), dtype: uint8
#   Image 54 shape: (768, 1024, 3), dtype: uint8
#   Image 55 shape: (768, 1024, 3), dtype: uint8
#   Image 56 shape: (768, 1024, 3), dtype: uint8
#   Image 57 shape: (768, 1024, 3), dtype: uint8
#   Image 58 shape: (768, 1024, 3), dtype: uint8
#   Image 59 shape: (768, 1024, 3), dtype: uint8
#   Image 60 shape: (768, 1024, 3), dtype: uint8
#   Image 61 shape: (768, 1024, 3), dtype: uint8
#   Image 62 shape: (768, 1024, 3), dtype: uint8
#   Image 63 shape: (768, 1024, 3), dtype: uint8
#   Image 64 shape: (768, 1024, 3), dtype: uint8
#   Image 65 shape: (768, 1024, 3), dtype: uint8
#   Image 66 shape: (768, 1024, 3), dtype: uint8
#   Image 67 shape: (768, 1024, 3), dtype: uint8
#   Image 68 shape: (768, 1024, 3), dtype: uint8
#   Image 69 shape: (768, 1024, 3), dtype: uint8
#   Image 70 shape: (768, 1024, 3), dtype: uint8
#   Image 71 shape: (768, 1024, 3), dtype: uint8
#   Image 72 shape: (768, 1024, 3), dtype: uint8
#   Image 73 shape: (768, 1024, 3), dtype: uint8
#   Image 74 shape: (768, 1024, 3), dtype: uint8
# 100%|██████████| 75/75 [00:12<00:00,  5.82it/s]
# ✅ Fingerprint for Samsung S21 FE saved to: /Users/shreetsu/prnu-camera-source-detection/fingerprints/Samsung S21 FE_fingerprint.npy

# %%
import os
import glob
from PIL import Image
import numpy as np
import sys

# >>>>>> CRITICAL: Import all necessary functions from the PRNU library <<<<<<
# You must ensure the 'prnu' library folder is correctly linked in your environment's path
try:
    from prnu import crosscorr_2d
    from prnu.functions import noise_extract_compact, rgb2gray 
except ImportError as e:
    sys.exit(f"❌ FATAL ERROR: Cannot import PRNU functions. Please check your setup. Error: {e}")
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

# --- CONFIGURATION ---
data_directory = r"/Users/shreetsu/prnu-camera-source-detection/data"
fingerprint_directory = os.path.join(os.path.dirname(data_directory), 'fingerprints')

# Define the folder to test and its known source
QUERY_FOLDER_PATH = r"/Users/shreetsu/prnu-camera-source-detection/data/iphone15/images/query_set/"
CORRECT_SOURCE = 'iphone15' 

# Standard resizing parameters
TARGET_WIDTH = 1024
TARGET_HEIGHT = 768

## ---------------------------------------------------------------------------
## PART 1: LOAD FINGERPRINTS
## ---------------------------------------------------------------------------

fingerprints = {}
for fp_file in os.listdir(fingerprint_directory):
    if fp_file.endswith('.npy'):
        device_name = fp_file.replace('_fingerprint.npy', '')
        fingerprints[device_name] = np.load(os.path.join(fingerprint_directory, fp_file))

if not fingerprints:
    sys.exit("❌ ERROR: No fingerprints loaded. Check the 'fingerprint_directory' path.")

print(f"Loaded {len(fingerprints)} fingerprints for matching: {list(fingerprints.keys())}")


## ---------------------------------------------------------------------------
## PART 2: BATCH MATCHING (CROSS-CORRELATION) AND ACCURACY
## ---------------------------------------------------------------------------
print("\n--- Starting Batch Traditional Correlation (PCE) Test ---")
print(f"Known correct source: {CORRECT_SOURCE}")

query_image_paths = glob.glob(os.path.join(QUERY_FOLDER_PATH, '*.[jJ][pP][gG]')) + \
                    glob.glob(os.path.join(QUERY_FOLDER_PATH, '*.[jJ][pP][eE][gG]'))

total_images = 0
correct_identifications = 0

if not query_image_paths:
    print("⚠️ No query images found in the specified folder.")
else:
    for image_path in query_image_paths:
        total_images += 1
        
        # 1. Image and Noise Residual Extraction 
        try:
            unknown_img = Image.open(image_path).convert('RGB')
            unknown_img = unknown_img.resize((TARGET_WIDTH, TARGET_HEIGHT), Image.LANCZOS)
            unknown_np = np.array(unknown_img, dtype=np.uint8)
        except:
            continue
        
        # Extract noise residual and convert to grayscale (Uses the actual PRNU functions)
        query_noise = noise_extract_compact((unknown_np, 4, 2))
        query_noise_gray = rgb2gray(query_noise)

        # 2. Compare against all fingerprints
        best_match_device = None
        highest_correlation = -1.0
        
        for device, fingerprint in fingerprints.items():

            if device == 'Samsung S21 FE':
                continue
            
            # Convert fingerprint to grayscale
            fp_gray = rgb2gray(fingerprint) if fingerprint.ndim == 3 else fingerprint

            # Calculate Cross-Correlation Score (PCE)
            correlation_map = crosscorr_2d(query_noise_gray, fp_gray)
            correlation_score = float(np.max(correlation_map))

            if correlation_score > highest_correlation:
                highest_correlation = correlation_score
                best_match_device = device
        
        # 3. Tally Accuracy
        is_correct = (best_match_device == CORRECT_SOURCE)
        
        if is_correct:
            correct_identifications += 1
            
        print(f"  Processed {os.path.basename(image_path):<30}: Identified as {best_match_device} ({'Correct' if is_correct else 'Incorrect'}). Score: {highest_correlation:.4f}")

## ---------------------------------------------------------------------------
## FINAL ACCURACY REPORT
## ---------------------------------------------------------------------------

print("\n" + "="*80)
print("           FINAL ACCURACY REPORT - TRADITIONAL CORRELATION")
print("="*80)

if total_images > 0:
    accuracy = (correct_identifications / total_images) * 100
    print(f"Total Images Processed: {total_images}")
    print(f"Correct Identifications: {correct_identifications}")
    print(f"Accuracy for {CORRECT_SOURCE} folder: **{accuracy:.2f}%** 🎯")
else:
    print("Could not calculate accuracy as zero valid images were processed.")
# Out:
# Loaded 4 fingerprints for matching: ['Samsung S21 FE', 'Samsung S23 5g', 'iphone15', 'OnePlus Nord CE4']
#
# --- Starting Batch Traditional Correlation (PCE) Test ---
# Known correct source: iphone15
#   Processed 43057B9A-694C-4E37-A08A-3CD7C5E67008.jpeg: Identified as iphone15 (Correct). Score: 2502.9805
#   Processed 289A1FCB-B1BA-44E1-BE5D-3B8BD9C38C6E.jpeg: Identified as iphone15 (Correct). Score: 2161.7659
#   Processed D14852A4-88F7-41F2-B129-CA366801ECF8.jpeg: Identified as iphone15 (Correct). Score: 3558.4363
#   Processed DF2F278B-931D-46E9-AF34-E9CF0971C8FE.jpeg: Identified as iphone15 (Correct). Score: 1188.0182
#   Processed 6A38C3E6-08D8-419C-A3EE-2E09D8CDCF14.jpeg: Identified as iphone15 (Correct). Score: 13591.2812
#   Processed AF779A1B-54B1-4F77-A27C-1487C79BD287.jpeg: Identified as iphone15 (Correct). Score: 5947.7139
#   Processed 695264B1-F405-4D27-B3E4-6FD6EB5E7E72.jpeg: Identified as iphone15 (Correct). Score: 2134.9695
#   Processed C40AE6E8-4517-4DD4-9AD7-2A7AEBC4D4C2.jpeg: Identified as iphone15 (Correct). Score: 1453.5198
#   Processed C133BDBD-841C-4AF7-8D1D-7C22AE8B97D2.jpeg: Identified as iphone15 (Correct). Score: 7101.9233
#   Processed 35603001-19CD-443C-A505-F024A7284C76.jpeg: Identified as iphone15 (Correct). Score: 2478.3015
#   Processed F9BEE323-3BAE-4963-9F8A-8663A081E1B3.jpeg: Identified as iphone15 (Correct). Score: 1538.9586
#   Processed D2F2FB59-E38B-41E4-ACF8-AF71C2E14F64.jpeg: Identified as iphone15 (Correct). Score: 5336.8740
#   Processed 80DC18F3-9E37-4A15-B2F8-2406D6ABC965.jpeg: Identified as iphone15 (Correct). Score: 10815.8721
#   Processed 4E30605E-7952-44B4-809A-10E230566D38.jpeg: Identified as iphone15 (Correct). Score: 2731.1831
#   Processed F3267C07-6B38-404A-BB47-4DF5019E9F85.jpeg: Identified as iphone15 (Correct). Score: 3095.2156
#   Processed 3030F9D8-0997-4839-9D08-5071DCE46F28.jpeg: Identified as iphone15 (Correct). Score: 12235.3545
#   Processed B73260EC-33C7-417C-A660-5289908AEAC3.jpeg: Identified as iphone15 (Correct). Score: 8803.9023
#   Processed 9EFC5E10-766B-477B-B2F3-38EF799AFDD1.jpeg: Identified as iphone15 (Correct). Score: 7598.8247
#   Processed 9E16432F-411F-45DF-8769-B7BFBAA8AAD0.jpeg: Identified as iphone15 (Correct). Score: 11788.3496
#   Processed 2F880A5A-CE36-4DF2-B60E-71627EDCA7EB.jpeg: Identified as iphone15 (Correct). Score: 4372.3213
#   Processed B1BB2134-0BBB-4F45-9F1F-687CC623182F.jpeg: Identified as iphone15 (Correct). Score: 6718.3994
#   Processed 2BBD21E0-C261-4D14-A6C1-71E9416994C1.jpeg: Identified as iphone15 (Correct). Score: 2678.9702
#   Processed FE1BCFC7-255A-4ED0-85F7-6055E5686352.jpeg: Identified as iphone15 (Correct). Score: 8467.3789
#   Processed 24F9C550-01D5-4EE6-83B0-90B666193912.jpeg: Identified as iphone15 (Correct). Score: 6489.7710
#   Processed F11B88FB-D43D-4B9A-9879-DAF1DF022267.jpeg: Identified as iphone15 (Correct). Score: 3446.6001
#   Processed D9D23C57-AA33-4CAA-9275-189B94FFA216.jpeg: Identified as iphone15 (Correct). Score: 13514.8379
#   Processed FE01DA30-43E8-4F41-992D-66B1AD4CAFAE.jpeg: Identified as iphone15 (Correct). Score: 3310.6658
#   Processed E7378955-FD91-4F87-9803-A03DDD3EE29D.jpeg: Identified as iphone15 (Correct). Score: 5020.9727
#   Processed 32041F16-FBF9-4C1F-8E97-CB3243063675.jpeg: Identified as iphone15 (Correct). Score: 7210.5234
#   Processed D568145E-C9ED-4C29-B85E-32CAE4769E51.jpeg: Identified as iphone15 (Correct). Score: 6289.0586
#   Processed B69DEC52-EA42-4C58-8BFC-3C32540C0F47.jpeg: Identified as iphone15 (Correct). Score: 4151.6504
#   Processed CD4C56F5-06CB-46A9-BF6E-899F3E28253D.jpeg: Identified as iphone15 (Correct). Score: 10757.5625
#   Processed 9E8BA55B-2D83-434A-BD4A-50C28C24EF31.jpeg: Identified as iphone15 (Correct). Score: 2057.6562
#   Processed 2EF4B5C1-53B8-4910-8727-B621FE85097D.jpeg: Identified as iphone15 (Correct). Score: 1986.4240
#   Processed FF56FA08-DD60-4AA1-9599-CE467262FED9.jpeg: Identified as iphone15 (Correct). Score: 1749.5472
#   Processed E0D6E978-06A6-4CBB-8CD2-8CC06ADB9398.jpeg: Identified as iphone15 (Correct). Score: 15273.8447
#
# ================================================================================
#            FINAL ACCURACY REPORT - TRADITIONAL CORRELATION
# ================================================================================
# Total Images Processed: 36
# Correct Identifications: 36
# Accuracy for iphone15 folder: **100.00%** 🎯
